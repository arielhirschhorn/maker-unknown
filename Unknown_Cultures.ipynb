# %%
import json
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import nltk
from nltk.stem import PorterStemmer as ps
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import WordPunctTokenizer
stemmer = ps()
from nltk.stem.cistem import Cistem
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
object_df = pd.read_pickle("./unknown_makers_FINAL.pkl")

# %%
#More information about collections, dates, descriptions
unknown_culture_df = object_df[(object_df['culture']=='') | (object_df['culture'] == '?')]

counts = unknown_culture_df.groupby(['credit', 'title', 'dating', 'description']).size()
counts_df = counts.to_frame().reset_index()
counts_df.columns = ['Credit', 'Title', 'Dating','Description','Object Count']
sorted_df = counts_df.sort_values('Object Count', ascending = False)
sorted_df
# Out:
#                                                  Credit  \
# 956                   Gift of Mr. John M. Sullivan, Jr.
# 2266        The Gorham Collection. Gift of Textron Inc.
# 2108                                  Museum Collection
# 281                      Georgianna Sayles Aldrich Fund
# 150
# 2260        The Gorham Collection. Gift of Textron Inc.
# 1298                         Gift of Mrs. Henry Vaughan
# 2158                           Museum Works of Art Fund
# 2074                                  Museum Collection
# 2175                           Museum Works of Art Fund
# 1687                              Gift of Thora Buckley
# 1248                       Gift of Mrs. Hans H. Zinsser
# 1854  Gift of the Society for the Preservation of Ne...
# 1080                      Gift of Mrs. Brenton G. Smith
# 1578                          Gift of Richard Greenleaf
# 1362           Gift of Mrs. John Howard Benson and sons
# 1806                       Gift of the Fazzano Brothers
# ...
